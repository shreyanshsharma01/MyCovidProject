# %% [markdown]
# List of status of Indian states and UT with covid 19

# %%
List_1_Name_of_States_UT_of_India=['Andaman and Nicobar',
'Andhra Pradesh',
'Arunachal',
'Assam',
'Bihar',
'Chandigarh',
'Chhattisgarh',
'Dadra & Nagar Haveli and Daman & Diu',
'Delhi',
'Goa',
'Gujarat',
'Haryana',
'Himachal Pradesh',
'Jammu and Kashmir',                                  
'Jharkhand',
'Karnataka',
'Kerala',
'Ladakh',
'Lakshadweep',
'Madhya Pradesh',
'Maharashtra',
'Manipur',
'Meghalaya',
'Mizoram',
'Nagaland',
'Odisha',
'Puducherry',
'Punjab',
'Rajasthan',
'Sikkim',
'Tamil Nadu',
'Telangana',
'Tripura',
'Uttar Pradesh',
'Uttarakhand',
'West Bengal']
len(List_1_Name_of_States_UT_of_India)
# Out:
# 36

# %%
List_2_population_of_States_UT=[380581.00,
49577103.00,
1383727.00,
31205576.00,
104099452.00,
1055450.00,
25545198.00,
585764.00,
16787941.00,
1458545.00,
60439692.00,
25351462.00,
6864602.00,
12267032.00,
32988134.00,
61095297.00,
33406061.00,
274000.00,
64473.00,
72626809.00,
112374333.00,
2570390.00,
2966889.00,
1097206.00,
1978502.00,
41974219.00,
1247953.00,
27743338.00,
68548437.00,
610577.00,
72147030.00,
35003674.00,
3673917.00,
199812341.00,
10086292.00,
91276115.00,
]

# %%
List_3_Data_of_infected_persons=[194,
40646,
609,
20646,
23589,
660,
4964,
585,
120107,
3304,
46430,
24797,
1417,
12757,
4921,
55115,
1066,
1151,
0,
21081,
292589,
1800,
403,
282,
956,
16110,
1832,
9442,
27789,
266,
160907,
42496,
2366,
45163,
4102,
38011]
len(List_3_Data_of_infected_persons)
# Out:
# 36

# %%
print("(Name_of_States_UT_of_India, Data_of_infected_persons)")
for i in range(len(List_1_Name_of_States_UT_of_India)):
    print('{} has {} infected persons'.format(List_1_Name_of_States_UT_of_India[i], List_3_Data_of_infected_persons[i]))
# Out:
# (Name_of_States_UT_of_India, Data_of_infected_persons)
# Andaman and Nicobar has 194 infected persons
# Andhra Pradesh has 40646 infected persons
# Arunachal has 609 infected persons
# Assam has 20646 infected persons
# Bihar has 23589 infected persons
# Chandigarh has 660 infected persons
# Chhattisgarh has 4964 infected persons
# Dadra & Nagar Haveli and Daman & Diu has 585 infected persons
# Delhi has 120107 infected persons
# Goa has 3304 infected persons
# Gujarat has 46430 infected persons
# Haryana has 24797 infected persons
# Himachal Pradesh has 1417 infected persons
# Jammu and Kashmir has 12757 infected persons
# Jharkhand has 4921 infected persons
# Karnataka has 55115 infected persons
# Kerala has 1066 infected persons
# Ladakh has 1151 infected persons
# Lakshadweep has 0 infected persons
# Madhya Pradesh has 21081 infected persons
# Maharashtra has 292589 infected persons
# Manipur has 1800 infected persons
# Meghalaya has 403 infected persons
# ...

# %%
List_4_Data_of_recovered_persons=[
142,
20298,
175,
14105,
14621,
480,
3512,
401,
99301,
1946,
32973,
18718,
1024,
6558,
2570,
20757,
4995,
973,
0,
14514,
16035700,
1163,
66,
160,
405,
1330,
1014,
6373,
20626,
90,
110807,
28705,
1684,
27634,
3021,
22253]
len(List_4_Data_of_recovered_persons)
# Out:
# 36

# %%
print("(Name_of_States_UT_of_India, Numbers_in_Recovered)")
for i in range(len(List_1_Name_of_States_UT_of_India)):
    LIST_5_Numbers_in_Recovered_in_Each_State=[(List_1_Name_of_States_UT_of_India[i],List_4_Data_of_recovered_persons[i])]
    for item in LIST_5_Numbers_in_Recovered_in_Each_State:
        print(item)
# Out:
# (Name_of_States_UT_of_India, Numbers_in_Recovered)
# ('Andaman and Nicobar', 142)
# ('Andhra Pradesh', 20298)
# ('Arunachal', 175)
# ('Assam', 14105)
# ('Bihar', 14621)
# ('Chandigarh', 480)
# ('Chhattisgarh', 3512)
# ('Dadra & Nagar Haveli and Daman & Diu', 401)
# ('Delhi', 99301)
# ('Goa', 1946)
# ('Gujarat', 32973)
# ('Haryana', 18718)
# ('Himachal Pradesh', 1024)
# ('Jammu and Kashmir', 6558)
# ('Jharkhand', 2570)
# ('Karnataka', 20757)
# ('Kerala', 4995)
# ('Ladakh', 973)
# ('Lakshadweep', 0)
# ('Madhya Pradesh', 14514)
# ('Maharashtra', 16035700)
# ('Manipur', 1163)
# ('Meghalaya', 66)
# ('Mizoram', 160)
# ('Nagaland', 405)
# ('Odisha', 1330)
# ('Puducherry', 1014)
# ('Punjab', 6373)
# ('Rajasthan', 20626)
# ('Sikkim', 90)
# ('Tamil Nadu', 110807)
# ('Telangana', 28705)
# ('Tripura', 1684)
# ('Uttar Pradesh', 27634)
# ('Uttarakhand', 3021)
# ('West Bengal', 22253)

# %%
print("Dictionary of Name of States-Ut and Number of Infected persons")
for i in range(len(List_1_Name_of_States_UT_of_India)): 
    STATE_INFECTED_DICTIONARY = {List_1_Name_of_States_UT_of_India[i]:List_3_Data_of_infected_persons[i]}
    for x,y in STATE_INFECTED_DICTIONARY.items():
        print(x,y)
# Out:
# Dictionary of Name of States-Ut and Number of Infected persons
# Andaman and Nicobar 194
# Andhra Pradesh 40646
# Arunachal 609
# Assam 20646
# Bihar 23589
# Chandigarh 660
# Chhattisgarh 4964
# Dadra & Nagar Haveli and Daman & Diu 585
# Delhi 120107
# Goa 3304
# Gujarat 46430
# Haryana 24797
# Himachal Pradesh 1417
# Jammu and Kashmir 12757
# Jharkhand 4921
# Karnataka 55115
# Kerala 1066
# Ladakh 1151
# Lakshadweep 0
# Madhya Pradesh 21081
# Maharashtra 292589
# Manipur 1800
# Meghalaya 403
# Mizoram 282
# Nagaland 956
# Odisha 16110
# Puducherry 1832
# Punjab 9442
# Rajasthan 27789
# Sikkim 266
# Tamil Nadu 160907
# Telangana 42496
# Tripura 2366
# Uttar Pradesh 45163
# Uttarakhand 4102
# West Bengal 38011

# %%
def IRR(recovered,infected): # Recovered infected Ratio
   try: 
       IRR=(recovered/infected)
       print("The IRR ={}%".format(IRR))
   except: 
       print('The IRR is Not possible')

# %%
for i in range (len(List_1_Name_of_States_UT_of_India)):
    print(List_1_Name_of_States_UT_of_India[i])
    IRR(List_4_Data_of_recovered_persons[i],List_3_Data_of_infected_persons[i])
# Out:
# Andaman and Nicobar
# The IRR =0.7319587628865979%
# Andhra Pradesh
# The IRR =0.49938493332677264%
# Arunachal
# The IRR =0.28735632183908044%
# Assam
# The IRR =0.6831831831831832%
# Bihar
# The IRR =0.6198227987621349%
# Chandigarh
# The IRR =0.7272727272727273%
# Chhattisgarh
# The IRR =0.7074939564867043%
# Dadra & Nagar Haveli and Daman & Diu
# The IRR =0.6854700854700855%
# Delhi
# The IRR =0.8267711290765734%
# Goa
# The IRR =0.5889830508474576%
# Gujarat
# The IRR =0.7101658410510446%
# Haryana
# The IRR =0.7548493769407589%
# Himachal Pradesh
# The IRR =0.7226534932956952%
# Jammu and Kashmir
# The IRR =0.5140707062789057%
# Jharkhand
# The IRR =0.5222515748831539%
# Karnataka
# The IRR =0.3766125374217545%
# Kerala
# The IRR =4.685741088180112%
# Ladakh
# The IRR =0.845351867940921%
# Lakshadweep
# The IRR is Not possible
# Madhya Pradesh
# The IRR =0.6884872634125516%
# Maharashtra
# The IRR =54.80622989927851%
# Manipur
# The IRR =0.6461111111111111%
# Meghalaya
# ...

# %%
List_6_Data_of_deceased_persons=[
0,
534,
3,
51,
201,
11,
23,
2,
3571,
21,
2106,
327,
11,
231,
46,
1147,
38,
1,
0,
697,
11452,
0,
2,
0,
0,
83,
25,
239,
0,
2,315,
403,
3,
1084,
51,
1049]
len(List_6_Data_of_deceased_persons)
# Out:
# 36

# %%
def CMR(death, total_population): #Crude Mortalitiy Rate
    CMR=death/total_population*100000;
    print("The Crude Mortality Rate ={}%".format(CMR))
print('The Crude Mortalitiy Rate of States & UT:')
for i in range(len(List_1_Name_of_States_UT_of_India)):
    print(List_1_Name_of_States_UT_of_India[i])
    CMR(List_6_Data_of_deceased_persons[i],List_2_population_of_States_UT[i])
# Out:
# The Crude Mortalitiy Rate of States & UT:
# Andaman and Nicobar
# The Crude Mortality Rate =0.0%
# Andhra Pradesh
# The Crude Mortality Rate =1.0771101328772679%
# Arunachal
# The Crude Mortality Rate =0.2168057716587159%
# Assam
# The Crude Mortality Rate =0.16343233017073616%
# Bihar
# The Crude Mortality Rate =0.19308458991695746%
# Chandigarh
# The Crude Mortality Rate =1.0422094841063054%
# Chhattisgarh
# The Crude Mortality Rate =0.0900364913985008%
# Dadra & Nagar Haveli and Daman & Diu
# The Crude Mortality Rate =0.34143443434557263%
# Delhi
# The Crude Mortality Rate =21.271220812605904%
# Goa
# The Crude Mortality Rate =1.4397910246169985%
# Gujarat
# The Crude Mortality Rate =3.4844651425424202%
# Haryana
# The Crude Mortality Rate =1.289866438472069%
# Himachal Pradesh
# The Crude Mortality Rate =0.16024235636676387%
# Jammu and Kashmir
# The Crude Mortality Rate =1.8830960903990468%
# Jharkhand
# The Crude Mortality Rate =0.13944408010468248%
# Karnataka
# ...

# %%
List_7_Data_of_active_persons=[
52,
19814,
431,
6490,
8767,
169,
1429,
182,
17235,
1337,
11351,
5752,
382,
5968,
2305,
33211,
6033,
177,
0,
5870,
120780,
637,
335,
122,
551,
4697,
793,
2830,
6617,
176,
47785,
13388,
679,
16445,
1030,
14709
]
# Out:
# 36

# %%
List_infected_persons=[sum(i) for i in zip(List_4_Data_of_recovered_persons, List_6_Data_of_deceased_persons, List_7_Data_of_active_persons)]
print('Data of infected persons:',format(List_infected_persons))
# Out:
# Data of infected persons: [194, 40646, 609, 20646, 23589, 660, 4964, 585, 120107, 3304, 46430, 24797, 1417, 12757, 4921, 55115, 11066, 1151, 0, 21081, 16167932, 1800, 403, 282, 956, 6110, 1832, 9442, 27243, 268, 158907, 42496, 2366, 45163, 4102, 38011]
